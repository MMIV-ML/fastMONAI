# %% [markdown]
# # Endometrical cancer segmentation - training

# %% [raw]
# ---
# skip_showdoc: true
# skip_exec: true
# ---

# %%
# Import the necessary modules
from fastMONAI.vision_all import *
from monai.networks.nets import UNet
from monai.losses import DiceCELoss

# %%
import SimpleITK as sitk

# disable warning messages globally
sitk.ProcessObject.SetGlobalWarningDisplay(False)

# %%
torch.cuda.set_device(0)

# %%
# Create a custom loss function using Tversky Focal Loss
loss_func = CustomLoss(loss_func=DiceCELoss(to_onehot_y=True, include_background=True, softmax=True))

# Create a UNet model with the specified parameters
model = UNet(spatial_dims=3, in_channels=1, out_channels=2, channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2), num_res_units=2).model

# %% [markdown]
# ## Train your own model

# %%
NB_DIR = Path.cwd()
DATA_DIR = NB_DIR/'..'/'data'/'EC'/'dev_julie'

# %%
# Read the data from the specified CSV file
df = pd.read_csv(DATA_DIR/'nifti_data.csv')
df.head(1)
# Out:
#                                                                                    img_path  \
# 0  /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_348.nii.gz
#
#                                                                                              mask_path  \
# 0  /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/org_mask/348segmentedJulie.nii.gz
#
#    subject_id  tumor_vol orientations  is_valid  rater
# 0         348       34.4          LPS     False  Julie

# %%
#Only using the validation labels from one rater. 
df = df.drop_duplicates(subset='subject_id', keep='first').reset_index(drop=True)

# %%
df.orientations.value_counts()
# Out:
# orientations
# LIP    50
# LPS    40
# LAS    27
# LSP    14
# LSA     1
# Name: count, dtype: int64

# %%
cat = [round(size,-1)for size in df.tumor_vol.tolist()]
df['cat'] = cat

# %%
df.cat.value_counts().plot(kind = 'bar')
plt.show()

# %%
df = df.loc[df.tumor_vol <= 300].reset_index(drop=True)

# %%
df.shape
# Out:
# (131, 8)

# %% [markdown]
# ### Look at training data

# %%
med_dataset = MedDataset(img_list=df.img_path.tolist(), max_workers=12);
# Out:
# The volumes in this dataset have different orientations. Recommended to pass in the argument reorder=True when creating a MedDataset object for this dataset

# %%
data_info_df = med_dataset.summary()

# %%
data_info_df
# Out:
#     dim_0  dim_1  dim_2  voxel_0  voxel_1  voxel_2 orientation  \
# 1     192    192     48   1.3021   1.3021      2.0        LPS+
# 0     192    192     48   1.3021   1.3021      2.0        LIP+
# 4     232    256     88   0.9766   0.9766      1.2        LPS+
# 3     232    256     88   0.9766   0.9766      1.2        LIP+
# 9     256    232     88   0.9766   0.9766      1.2        LIP+
# 11    320    248    104   0.9375   0.9375      1.2        LPS+
# 7     248    320    104   0.9375   0.9375      1.2        LIP+
# 8     248    320    104   1.0312   1.0312      1.2        LIP+
# 12    320    248    104   1.0312   1.0312      1.2        LPS+
# 2     192    192     48   1.3021   1.3021      2.2        LIP+
# 5     232    256     88   0.9766   0.9766      1.2        LSA+
# 6     240    320    104   1.0312   1.0312      1.2        LIP+
# 10    256    232     96   0.9766   0.9766      1.2        LIP+
#
#                                                                                 example_path  \
# 1   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_011.nii.gz
# 0   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_022.nii.gz
# 4   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_367.nii.gz
# 3   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_372.nii.gz
# 9   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_352.nii.gz
# 11  /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_337.nii.gz
# 7   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_336.nii.gz
# 8   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_346.nii.gz
# 12  /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_347.nii.gz
# 2   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_097.nii.gz
# 5   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_434.nii.gz
# 6   /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_344.nii.gz
# 10  /home/sathiesh/lib_dev/fastMONAI/research_ec/../data/EC/dev_julie/nii_img/img_553.nii.gz
#
#     total
# 1      38
# 0      25
# 4      22
# 3      21
# 9       9
# 11      4
# 7       3
# 8       3
# 12      2
# 2       1
# 5       1
# 6       1
# 10      1

# %%
# Get the suggested resampling and reordering values from the dataset
resample, reorder = med_dataset.suggestion()
resample, reorder
# Out:
# ([1.3021, 1.3021, 1.2], False)

# %%
resample = [1, 1, 1]

# %%
# Get the largest image size from the dataset, using the specified resampling values
img_size = med_dataset.get_largest_img_size(resample = resample)
img_size
# Out:
# [330.0, 330.0, 125.0]

# %%
size = [160, 160, 128]
bs = 8

# %% [markdown]
# ### Create MedDataBlock and Learner

# %%
# Create a list of transformations to apply to the images, with a probability of 0.5 for each transformation being applied
item_tfms = [ZNormalization(), PadOrCrop(size), RandomAffine(scales=(0.9, 1.2), degrees=20, p=0.5),
             RandomFlip(), RandomGamma(log_gamma=(-0.2, 0.2), p=0.5)]

# %%
# Create a MedDataBlock with the specified blocks, splitter, and item transformations

dblock = MedDataBlock(blocks=(ImageBlock(cls=MedImage), MedMaskBlock), 
                      splitter=ColSplitter('is_valid'),
                      get_x=ColReader('img_path'),
                      get_y=ColReader('mask_path'),
                      item_tfms=item_tfms,
                      reorder=reorder,
                      resample=resample)

# %%
dls = dblock.dataloaders(df, bs=bs)

# %%
# training and validation
len(dls.train_ds.items), len(dls.valid_ds.items)
# Out:
# (100, 31)

# %%
dls.show_batch(unique=False, max_n=4, anatomical_plane=2)

# %%
learn = Learner(dls, model, loss_func=loss_func, opt_func= ranger, metrics=multi_dice_score)

# %%
lr=learn.lr_find()
lr
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0030199517495930195)

# %%
lr = 0.01

# %%
learn.fit_flat_cos(100,lr, cbs=SaveModelCallback(fname='ec-unet', monitor='multi_dice_score', min_delta=0.005))

# %% [markdown]
# Better model found at epoch 94 with multi_dice_score value: 0.7574766278266907.

# %%
learn.recorder.plot_loss()

# %%
learn.show_results(max_n=4, anatomical_plane=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
store_variables(pkl_fn='models/vars.pkl', size=size, reorder=reorder, resample=resample)

# %%
learn.export(f'models/learner.pkl')
